# %%
# Import the dependencies.
import pandas as pd
import matplotlib.pyplot as plt
import numpy as np
from citipy import citipy
from datetime import datetime
import requests
from config import weather_api_key

# %%
# Create a set of random latitude and longitude combinations.
lats = np.random.uniform(low=-90.000, high=90.000, size=2000)
lngs = np.random.uniform(low=-180.000, high=180.000, size=2000)
lat_lngs = zip(lats, lngs)
lat_lngs

# %%
# Add the latitudes and longitudes to a list.
coordinates = list(lat_lngs)

# %%
# Create a list for holding the cities.
cities = []
# Identify the nearest city for each latitude and longitude combination.
for coordinate in coordinates:
    city = citipy.nearest_city(coordinate[0], coordinate[1]).city_name
    # If the city is unique, then we will add it to the cities list.
    if city not in cities:
        cities.append(city)
# Print the city count to confirm sufficient count.
len(cities)
# Out:
# 752

# %%
# Starting URL for Weather Map API Call.
url = "http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=" + weather_api_key

# %%
# Create an empty list to hold the weather data.
city_data = []

# Print the beginning of the logging.
print("Beginning Data Retrieval     ")
print("-----------------------------")

# Create counters.
record_count = 1
set_count = 1

# Loop through all the cities in the list.
for i, city in enumerate(cities):

    # Group cities in sets of 50 for logging purposes.
    if (i % 50 == 0 and i >= 50):
        set_count += 1
        record_count = 1
        
    # Create endpoint URL with each city.
    city_url = url + "&q=" + city.replace(" ","+")

    # Log the URL, record, and set numbers and the city.
    print(f"Processing Record {record_count} of Set {set_count} | {city}")
    
    # Add 1 to the record count.
    record_count += 1
    
    # Run an API request for each of the cities.
    try:
        # Parse the JSON and retrieve data.
        city_weather = requests.get(city_url).json()
        # Parse out the needed data.
        city_lat = city_weather["coord"]["lat"]
        city_lng = city_weather["coord"]["lon"]
        city_max_temp = city_weather["main"]["temp_max"]
        city_humidity = city_weather["main"]["humidity"]
        city_clouds = city_weather["clouds"]["all"]
        city_wind = city_weather["wind"]["speed"]
        city_country = city_weather["sys"]["country"]
        city_description = city_weather["weather"][0]["description"]
        
        # Convert the date to ISO standard.
        city_date = datetime.utcfromtimestamp(city_weather["dt"]).strftime('%Y-%m-%d %H:%M:%S')
        
        # Append the city information into city_data list.
        city_data.append({"City": city.title(),
                          "Lat": city_lat,
                          "Lng": city_lng,
                          "Max Temp": city_max_temp,
                          "Humidity": city_humidity,
                          "Cloudiness": city_clouds,
                          "Wind Speed": city_wind,
                          "Country": city_country,
                          "Date": city_date,
                          "Current Description": city_description})
                        

    # If an error is experienced, skip the city.
    except:
        print("City not found. Skipping... " + city)
        pass

# Indicate that Data Loading is complete.
print("-----------------------------")
print("Data Retrieval Complete      ")
print("-----------------------------")
# Out:
# Beginning Data Retrieval
# -----------------------------
# Processing Record 1 of Set 1 | new norfolk
# Processing Record 2 of Set 1 | tura
# Processing Record 3 of Set 1 | attawapiskat
# City not found. Skipping... attawapiskat
# Processing Record 4 of Set 1 | muli
# Processing Record 5 of Set 1 | vaini
# Processing Record 6 of Set 1 | marienburg
# Processing Record 7 of Set 1 | dikson
# Processing Record 8 of Set 1 | thompson
# Processing Record 9 of Set 1 | emerald
# Processing Record 10 of Set 1 | ushuaia
# Processing Record 11 of Set 1 | jamestown
# Processing Record 12 of Set 1 | severo-kurilsk
# Processing Record 13 of Set 1 | taolanaro
# City not found. Skipping... taolanaro
# Processing Record 14 of Set 1 | kodiak
# Processing Record 15 of Set 1 | ishigaki
# Processing Record 16 of Set 1 | kapaa
# Processing Record 17 of Set 1 | svetlogorsk
# Processing Record 18 of Set 1 | marsabit
# Processing Record 19 of Set 1 | pokosnoye
# Processing Record 20 of Set 1 | havre-saint-pierre
# Processing Record 21 of Set 1 | hovd
# Processing Record 22 of Set 1 | salinas
# Processing Record 23 of Set 1 | albany
# Processing Record 24 of Set 1 | brahmapuri
# City not found. Skipping... brahmapuri
# Processing Record 25 of Set 1 | iqaluit
# Processing Record 26 of Set 1 | noumea
# Processing Record 27 of Set 1 | haibowan
# City not found. Skipping... haibowan
# Processing Record 28 of Set 1 | husavik
# Processing Record 29 of Set 1 | wanning
# Processing Record 30 of Set 1 | khatanga
# Processing Record 31 of Set 1 | tukuran
# Processing Record 32 of Set 1 | los llanos de aridane
# Processing Record 33 of Set 1 | rikitea
# Processing Record 34 of Set 1 | kaitangata
# Processing Record 35 of Set 1 | sentyabrskiy
# City not found. Skipping... sentyabrskiy
# Processing Record 36 of Set 1 | balsas
# Processing Record 37 of Set 1 | raudeberg
# Processing Record 38 of Set 1 | bluff
# Processing Record 39 of Set 1 | barrow
# Processing Record 40 of Set 1 | jalu
# Processing Record 41 of Set 1 | butaritari
# Processing Record 42 of Set 1 | saldanha
# Processing Record 43 of Set 1 | hasanabad
# Processing Record 44 of Set 1 | atuona
# Processing Record 45 of Set 1 | qaanaaq
# Processing Record 46 of Set 1 | pampas
# Processing Record 47 of Set 1 | bentiu
# Processing Record 48 of Set 1 | komsomolskiy
# Processing Record 49 of Set 1 | busselton
# Processing Record 50 of Set 1 | saint-joseph
# Processing Record 1 of Set 2 | sur
# Processing Record 2 of Set 2 | nome
# Processing Record 3 of Set 2 | sept-iles
# Processing Record 4 of Set 2 | cherskiy
# Processing Record 5 of Set 2 | tiksi
# Processing Record 6 of Set 2 | longyearbyen
# Processing Record 7 of Set 2 | cabo san lucas
# Processing Record 8 of Set 2 | illoqqortoormiut
# City not found. Skipping... illoqqortoormiut
# Processing Record 9 of Set 2 | airai
# Processing Record 10 of Set 2 | qinggang
# Processing Record 11 of Set 2 | saint george
# Processing Record 12 of Set 2 | bontang
# Processing Record 13 of Set 2 | tuktoyaktuk
# Processing Record 14 of Set 2 | yellowknife
# Processing Record 15 of Set 2 | labutta
# City not found. Skipping... labutta
# Processing Record 16 of Set 2 | port hardy
# Processing Record 17 of Set 2 | cobija
# Processing Record 18 of Set 2 | hobart
# Processing Record 19 of Set 2 | nhulunbuy
# Processing Record 20 of Set 2 | castro
# Processing Record 21 of Set 2 | rio grande
# Processing Record 22 of Set 2 | naze
# Processing Record 23 of Set 2 | port alfred
# Processing Record 24 of Set 2 | togur
# Processing Record 25 of Set 2 | aswan
# Processing Record 26 of Set 2 | namibe
# Processing Record 27 of Set 2 | yerbogachen
# Processing Record 28 of Set 2 | nuuk
# Processing Record 29 of Set 2 | laguna
# Processing Record 30 of Set 2 | guerrero negro
# Processing Record 31 of Set 2 | katsuura
# Processing Record 32 of Set 2 | itigi
# Processing Record 33 of Set 2 | pisco
# Processing Record 34 of Set 2 | atasu
# Processing Record 35 of Set 2 | mar del plata
# Processing Record 36 of Set 2 | gualaquiza
# Processing Record 37 of Set 2 | adrar
# Processing Record 38 of Set 2 | yar-sale
# Processing Record 39 of Set 2 | morehead
# Processing Record 40 of Set 2 | vardo
# Processing Record 41 of Set 2 | lagoa
# Processing Record 42 of Set 2 | ponferrada
# Processing Record 43 of Set 2 | fortuna
# Processing Record 44 of Set 2 | oranjemund
# Processing Record 45 of Set 2 | prince rupert
# Processing Record 46 of Set 2 | punta arenas
# Processing Record 47 of Set 2 | lebu
# Processing Record 48 of Set 2 | broome
# Processing Record 49 of Set 2 | safford
# Processing Record 50 of Set 2 | grobina
# Processing Record 1 of Set 3 | ugoofaaru
# Processing Record 2 of Set 3 | hermanus
# Processing Record 3 of Set 3 | belle fourche
# Processing Record 4 of Set 3 | torbay
# Processing Record 5 of Set 3 | sitka
# Processing Record 6 of Set 3 | tsihombe
# City not found. Skipping... tsihombe
# Processing Record 7 of Set 3 | mahebourg
# Processing Record 8 of Set 3 | port hedland
# Processing Record 9 of Set 3 | east london
# Processing Record 10 of Set 3 | lompoc
# Processing Record 11 of Set 3 | totness
# Processing Record 12 of Set 3 | avarua
# Processing Record 13 of Set 3 | bambous virieux
# Processing Record 14 of Set 3 | port elizabeth
# Processing Record 15 of Set 3 | faanui
# Processing Record 16 of Set 3 | ribeira grande
# Processing Record 17 of Set 3 | maracacume
# Processing Record 18 of Set 3 | kamenka
# Processing Record 19 of Set 3 | chokurdakh
# Processing Record 20 of Set 3 | am timan
# Processing Record 21 of Set 3 | leningradskiy
# Processing Record 22 of Set 3 | tuatapere
# Processing Record 23 of Set 3 | hilo
# Processing Record 24 of Set 3 | san rafael
# Processing Record 25 of Set 3 | cape town
# Processing Record 26 of Set 3 | auki
# Processing Record 27 of Set 3 | ayagoz
# Processing Record 28 of Set 3 | hithadhoo
# Processing Record 29 of Set 3 | ponta delgada
# Processing Record 30 of Set 3 | saleaula
# City not found. Skipping... saleaula
# Processing Record 31 of Set 3 | yulara
# Processing Record 32 of Set 3 | bethel
# Processing Record 33 of Set 3 | thurso
# Processing Record 34 of Set 3 | tateyama
# Processing Record 35 of Set 3 | bredasdorp
# Processing Record 36 of Set 3 | bilma
# Processing Record 37 of Set 3 | cape canaveral
# Processing Record 38 of Set 3 | upernavik
# Processing Record 39 of Set 3 | nizhneyansk
# City not found. Skipping... nizhneyansk
# Processing Record 40 of Set 3 | mataura
# Processing Record 41 of Set 3 | souillac
# Processing Record 42 of Set 3 | mafeteng
# Processing Record 43 of Set 3 | azuaga
# Processing Record 44 of Set 3 | stepnyak
# Processing Record 45 of Set 3 | porto novo
# Processing Record 46 of Set 3 | lagunas
# Processing Record 47 of Set 3 | fairview
# Processing Record 48 of Set 3 | talnakh
# Processing Record 49 of Set 3 | jutai
# Processing Record 50 of Set 3 | faya
# Processing Record 1 of Set 4 | carnarvon
# Processing Record 2 of Set 4 | pudozh
# Processing Record 3 of Set 4 | lokoja
# Processing Record 4 of Set 4 | arraial do cabo
# Processing Record 5 of Set 4 | puerto ayora
# Processing Record 6 of Set 4 | touros
# Processing Record 7 of Set 4 | teya
# Processing Record 8 of Set 4 | nogliki
# Processing Record 9 of Set 4 | codrington
# Processing Record 10 of Set 4 | dakar
# Processing Record 11 of Set 4 | port augusta
# Processing Record 12 of Set 4 | ndende
# Processing Record 13 of Set 4 | cap malheureux
# Processing Record 14 of Set 4 | yermakovskoye
# Processing Record 15 of Set 4 | upata
# Processing Record 16 of Set 4 | pasni
# Processing Record 17 of Set 4 | bodden town
# Processing Record 18 of Set 4 | banda aceh
# Processing Record 19 of Set 4 | celestun
# Processing Record 20 of Set 4 | choix
# Processing Record 21 of Set 4 | alice springs
# Processing Record 22 of Set 4 | nikolskoye
# Processing Record 23 of Set 4 | puerto escondido
# Processing Record 24 of Set 4 | lasa
# Processing Record 25 of Set 4 | mayo
# Processing Record 26 of Set 4 | barentsburg
# City not found. Skipping... barentsburg
# Processing Record 27 of Set 4 | bakchar
# Processing Record 28 of Set 4 | marawi
# Processing Record 29 of Set 4 | newala
# Processing Record 30 of Set 4 | louisbourg
# City not found. Skipping... louisbourg
# Processing Record 31 of Set 4 | krasnoselkup
# Processing Record 32 of Set 4 | krasnyy chikoy
# Processing Record 33 of Set 4 | kingaroy
# Processing Record 34 of Set 4 | amderma
# City not found. Skipping... amderma
# Processing Record 35 of Set 4 | sinnamary
# Processing Record 36 of Set 4 | naryan-mar
# Processing Record 37 of Set 4 | abu dhabi
# Processing Record 38 of Set 4 | nouadhibou
# Processing Record 39 of Set 4 | coracora
# Processing Record 40 of Set 4 | wad madani
# Processing Record 41 of Set 4 | nicoya
# Processing Record 42 of Set 4 | ilulissat
# Processing Record 43 of Set 4 | hasaki
# Processing Record 44 of Set 4 | sao felix do xingu
# Processing Record 45 of Set 4 | mount isa
# Processing Record 46 of Set 4 | chuy
# Processing Record 47 of Set 4 | yerofey pavlovich
# Processing Record 48 of Set 4 | bonthe
# Processing Record 49 of Set 4 | buraydah
# Processing Record 50 of Set 4 | sawtell
# Processing Record 1 of Set 5 | tavda
# Processing Record 2 of Set 5 | shenjiamen
# Processing Record 3 of Set 5 | arrecife
# Processing Record 4 of Set 5 | samusu
# City not found. Skipping... samusu
# Processing Record 5 of Set 5 | boddam
# Processing Record 6 of Set 5 | isangel
# Processing Record 7 of Set 5 | skovde
# City not found. Skipping... skovde
# Processing Record 8 of Set 5 | krasnaya gorka
# Processing Record 9 of Set 5 | ahipara
# Processing Record 10 of Set 5 | xaltianguis
# Processing Record 11 of Set 5 | marcona
# City not found. Skipping... marcona
# Processing Record 12 of Set 5 | ilo
# Processing Record 13 of Set 5 | taonan
# Processing Record 14 of Set 5 | qasigiannguit
# Processing Record 15 of Set 5 | suriapet
# Processing Record 16 of Set 5 | pevek
# Processing Record 17 of Set 5 | yining
# Processing Record 18 of Set 5 | man
# Processing Record 19 of Set 5 | sao joao da barra
# Processing Record 20 of Set 5 | hamilton
# Processing Record 21 of Set 5 | tran
# Processing Record 22 of Set 5 | shingu
# Processing Record 23 of Set 5 | sungaipenuh
# Processing Record 24 of Set 5 | nangomba
# Processing Record 25 of Set 5 | esperance
# Processing Record 26 of Set 5 | las navas
# Processing Record 27 of Set 5 | vanavara
# Processing Record 28 of Set 5 | hay river
# Processing Record 29 of Set 5 | meyungs
# City not found. Skipping... meyungs
# Processing Record 30 of Set 5 | palmer
# Processing Record 31 of Set 5 | luderitz
# Processing Record 32 of Set 5 | portland
# Processing Record 33 of Set 5 | suoyarvi
# Processing Record 34 of Set 5 | ponta do sol
# Processing Record 35 of Set 5 | morant bay
# Processing Record 36 of Set 5 | reyes
# Processing Record 37 of Set 5 | warrington
# Processing Record 38 of Set 5 | trinidad
# Processing Record 39 of Set 5 | guajara-mirim
# City not found. Skipping... guajara-mirim
# Processing Record 40 of Set 5 | santa marta
# Processing Record 41 of Set 5 | twin falls
# Processing Record 42 of Set 5 | chikwawa
# Processing Record 43 of Set 5 | gat
# Processing Record 44 of Set 5 | omboue
# Processing Record 45 of Set 5 | lorengau
# Processing Record 46 of Set 5 | nanortalik
# Processing Record 47 of Set 5 | bud
# Processing Record 48 of Set 5 | mahon
# Processing Record 49 of Set 5 | thongwa
# Processing Record 50 of Set 5 | saint-pierre
# Processing Record 1 of Set 6 | netivot
# Processing Record 2 of Set 6 | sindor
# Processing Record 3 of Set 6 | vestmannaeyjar
# Processing Record 4 of Set 6 | provideniya
# Processing Record 5 of Set 6 | kruisfontein
# Processing Record 6 of Set 6 | takoradi
# Processing Record 7 of Set 6 | khandyga
# Processing Record 8 of Set 6 | natal
# Processing Record 9 of Set 6 | dali
# Processing Record 10 of Set 6 | burns lake
# Processing Record 11 of Set 6 | nova olinda do norte
# Processing Record 12 of Set 6 | abong mbang
# Processing Record 13 of Set 6 | rocha
# Processing Record 14 of Set 6 | ibra
# Processing Record 15 of Set 6 | skovorodino
# Processing Record 16 of Set 6 | ankazoabo
# Processing Record 17 of Set 6 | avera
# Processing Record 18 of Set 6 | yuanping
# Processing Record 19 of Set 6 | olinda
# Processing Record 20 of Set 6 | kuche
# City not found. Skipping... kuche
# Processing Record 21 of Set 6 | west fargo
# Processing Record 22 of Set 6 | kahului
# Processing Record 23 of Set 6 | sao filipe
# Processing Record 24 of Set 6 | dukat
# Processing Record 25 of Set 6 | baykit
# Processing Record 26 of Set 6 | constitucion
# Processing Record 27 of Set 6 | kodinsk
# Processing Record 28 of Set 6 | vagur
# Processing Record 29 of Set 6 | etchoropo
# Processing Record 30 of Set 6 | namatanai
# Processing Record 31 of Set 6 | jacareacanga
# Processing Record 32 of Set 6 | soe
# Processing Record 33 of Set 6 | bilibino
# Processing Record 34 of Set 6 | bruckmuhl
# Processing Record 35 of Set 6 | morwell
# Processing Record 36 of Set 6 | hambantota
# Processing Record 37 of Set 6 | itoman
# Processing Record 38 of Set 6 | fortuna foothills
# Processing Record 39 of Set 6 | san patricio
# Processing Record 40 of Set 6 | pershotravneve
# Processing Record 41 of Set 6 | anloga
# Processing Record 42 of Set 6 | huarmey
# Processing Record 43 of Set 6 | eyl
# Processing Record 44 of Set 6 | manokwari
# Processing Record 45 of Set 6 | norman wells
# Processing Record 46 of Set 6 | veshenskaya
# Processing Record 47 of Set 6 | makakilo city
# Processing Record 48 of Set 6 | oyama
# Processing Record 49 of Set 6 | akdepe
# Processing Record 50 of Set 6 | norfolk
# Processing Record 1 of Set 7 | gangotri
# City not found. Skipping... gangotri
# Processing Record 2 of Set 7 | coihaique
# Processing Record 3 of Set 7 | waingapu
# Processing Record 4 of Set 7 | burayevo
# Processing Record 5 of Set 7 | sobolevo
# Processing Record 6 of Set 7 | padang
# Processing Record 7 of Set 7 | siteki
# Processing Record 8 of Set 7 | clyde river
# Processing Record 9 of Set 7 | kavieng
# Processing Record 10 of Set 7 | qui nhon
# Processing Record 11 of Set 7 | bathsheba
# Processing Record 12 of Set 7 | saint-philippe
# Processing Record 13 of Set 7 | batsfjord
# Processing Record 14 of Set 7 | sioux lookout
# Processing Record 15 of Set 7 | athmallik
# Processing Record 16 of Set 7 | carai
# Processing Record 17 of Set 7 | voh
# Processing Record 18 of Set 7 | mys shmidta
# City not found. Skipping... mys shmidta
# Processing Record 19 of Set 7 | santa rosa
# Processing Record 20 of Set 7 | balfour
# Processing Record 21 of Set 7 | sechura
# Processing Record 22 of Set 7 | peniche
# Processing Record 23 of Set 7 | san ignacio
# Processing Record 24 of Set 7 | dicabisagan
# Processing Record 25 of Set 7 | grand river south east
# City not found. Skipping... grand river south east
# Processing Record 26 of Set 7 | limbe
# Processing Record 27 of Set 7 | vila velha
# Processing Record 28 of Set 7 | paveh
# Processing Record 29 of Set 7 | anadyr
# Processing Record 30 of Set 7 | genhe
# Processing Record 31 of Set 7 | minab
# Processing Record 32 of Set 7 | paraiso
# Processing Record 33 of Set 7 | tasiilaq
# Processing Record 34 of Set 7 | victoria
# Processing Record 35 of Set 7 | hawalli
# Processing Record 36 of Set 7 | ontario
# Processing Record 37 of Set 7 | dunedin
# Processing Record 38 of Set 7 | honningsvag
# Processing Record 39 of Set 7 | tabou
# Processing Record 40 of Set 7 | maltahohe
# Processing Record 41 of Set 7 | harper
# Processing Record 42 of Set 7 | cidreira
# Processing Record 43 of Set 7 | belushya guba
# City not found. Skipping... belushya guba
# Processing Record 44 of Set 7 | helong
# Processing Record 45 of Set 7 | dunda
# Processing Record 46 of Set 7 | caravelas
# Processing Record 47 of Set 7 | lavrentiya
# Processing Record 48 of Set 7 | saskylakh
# Processing Record 49 of Set 7 | varca
# Processing Record 50 of Set 7 | robertsport
# Processing Record 1 of Set 8 | fare
# Processing Record 2 of Set 8 | cortez
# Processing Record 3 of Set 8 | grindavik
# Processing Record 4 of Set 8 | kyabe
# Processing Record 5 of Set 8 | gopalur
# Processing Record 6 of Set 8 | ulaanbaatar
# Processing Record 7 of Set 8 | zyryanka
# Processing Record 8 of Set 8 | sinop
# Processing Record 9 of Set 8 | oswego
# Processing Record 10 of Set 8 | sterling
# Processing Record 11 of Set 8 | amapa
# Processing Record 12 of Set 8 | college
# Processing Record 13 of Set 8 | san quintin
# Processing Record 14 of Set 8 | terney
# Processing Record 15 of Set 8 | pochutla
# Processing Record 16 of Set 8 | alcamo
# Processing Record 17 of Set 8 | geraldton
# Processing Record 18 of Set 8 | kabare
# Processing Record 19 of Set 8 | ancud
# Processing Record 20 of Set 8 | toliary
# City not found. Skipping... toliary
# Processing Record 21 of Set 8 | kamenskoye
# City not found. Skipping... kamenskoye
# Processing Record 22 of Set 8 | muriwai beach
# Processing Record 23 of Set 8 | san joaquin
# Processing Record 24 of Set 8 | vadinsk
# Processing Record 25 of Set 8 | kouango
# Processing Record 26 of Set 8 | lakes entrance
# Processing Record 27 of Set 8 | jizan
# Processing Record 28 of Set 8 | cabra
# Processing Record 29 of Set 8 | matamoros
# Processing Record 30 of Set 8 | quatre cocos
# Processing Record 31 of Set 8 | lanzhou
# Processing Record 32 of Set 8 | samarai
# Processing Record 33 of Set 8 | barawe
# City not found. Skipping... barawe
# Processing Record 34 of Set 8 | srednekolymsk
# Processing Record 35 of Set 8 | manzanares
# Processing Record 36 of Set 8 | corinto
# Processing Record 37 of Set 8 | chinhoyi
# Processing Record 38 of Set 8 | fort nelson
# Processing Record 39 of Set 8 | santa vitoria do palmar
# Processing Record 40 of Set 8 | hualmay
# Processing Record 41 of Set 8 | palu
# Processing Record 42 of Set 8 | qaqortoq
# Processing Record 43 of Set 8 | ekhabi
# Processing Record 44 of Set 8 | ouadda
# Processing Record 45 of Set 8 | evensk
# Processing Record 46 of Set 8 | hailar
# Processing Record 47 of Set 8 | bengkulu
# Processing Record 48 of Set 8 | coquimbo
# Processing Record 49 of Set 8 | sambava
# Processing Record 50 of Set 8 | coxim
# Processing Record 1 of Set 9 | victor harbor
# Processing Record 2 of Set 9 | tutoia
# Processing Record 3 of Set 9 | zhigansk
# Processing Record 4 of Set 9 | great bend
# Processing Record 5 of Set 9 | kytmanovo
# Processing Record 6 of Set 9 | halalo
# City not found. Skipping... halalo
# Processing Record 7 of Set 9 | miandrivazo
# Processing Record 8 of Set 9 | mtambile
# Processing Record 9 of Set 9 | nilanga
# Processing Record 10 of Set 9 | alofi
# Processing Record 11 of Set 9 | yirol
# City not found. Skipping... yirol
# Processing Record 12 of Set 9 | gloucester
# Processing Record 13 of Set 9 | celendin
# Processing Record 14 of Set 9 | sisophon
# Processing Record 15 of Set 9 | talcahuano
# Processing Record 16 of Set 9 | yaan
# Processing Record 17 of Set 9 | hurghada
# Processing Record 18 of Set 9 | kralendijk
# Processing Record 19 of Set 9 | moron
# Processing Record 20 of Set 9 | asau
# Processing Record 21 of Set 9 | paamiut
# Processing Record 22 of Set 9 | pousat
# City not found. Skipping... pousat
# Processing Record 23 of Set 9 | mombetsu
# Processing Record 24 of Set 9 | novouzensk
# Processing Record 25 of Set 9 | gamba
# Processing Record 26 of Set 9 | aykhal
# Processing Record 27 of Set 9 | haines junction
# Processing Record 28 of Set 9 | maceio
# Processing Record 29 of Set 9 | beringovskiy
# Processing Record 30 of Set 9 | malpe
# Processing Record 31 of Set 9 | muscat
# Processing Record 32 of Set 9 | sandila
# Processing Record 33 of Set 9 | aklavik
# Processing Record 34 of Set 9 | serenje
# Processing Record 35 of Set 9 | yongan
# Processing Record 36 of Set 9 | novyy urgal
# Processing Record 37 of Set 9 | santa maria
# Processing Record 38 of Set 9 | praia da vitoria
# Processing Record 39 of Set 9 | kaka
# Processing Record 40 of Set 9 | biltine
# Processing Record 41 of Set 9 | the valley
# Processing Record 42 of Set 9 | holme
# Processing Record 43 of Set 9 | san cristobal
# Processing Record 44 of Set 9 | matara
# Processing Record 45 of Set 9 | puerto leguizamo
# Processing Record 46 of Set 9 | port macquarie
# Processing Record 47 of Set 9 | santa barbara
# Processing Record 48 of Set 9 | chapais
# Processing Record 49 of Set 9 | vaitape
# Processing Record 50 of Set 9 | tianpeng
# Processing Record 1 of Set 10 | saint-augustin
# Processing Record 2 of Set 10 | faranah
# Processing Record 3 of Set 10 | tucurui
# Processing Record 4 of Set 10 | itarema
# Processing Record 5 of Set 10 | kupang
# Processing Record 6 of Set 10 | chinchani
# Processing Record 7 of Set 10 | te anau
# Processing Record 8 of Set 10 | okakarara
# Processing Record 9 of Set 10 | finnsnes
# Processing Record 10 of Set 10 | iranshahr
# Processing Record 11 of Set 10 | agadez
# Processing Record 12 of Set 10 | cieza
# Processing Record 13 of Set 10 | krasnoyarka
# Processing Record 14 of Set 10 | sulangan
# Processing Record 15 of Set 10 | podgornoye
# Processing Record 16 of Set 10 | praya
# Processing Record 17 of Set 10 | formosa
# Processing Record 18 of Set 10 | muros
# Processing Record 19 of Set 10 | homer
# Processing Record 20 of Set 10 | san ramon
# Processing Record 21 of Set 10 | ovre ardal
# Processing Record 22 of Set 10 | north battleford
# Processing Record 23 of Set 10 | klaksvik
# Processing Record 24 of Set 10 | vila franca do campo
# Processing Record 25 of Set 10 | spornoye
# Processing Record 26 of Set 10 | georgetown
# Processing Record 27 of Set 10 | umrala
# Processing Record 28 of Set 10 | tshikapa
# Processing Record 29 of Set 10 | nizhniy odes
# Processing Record 30 of Set 10 | leshukonskoye
# Processing Record 31 of Set 10 | okrika
# Processing Record 32 of Set 10 | kununurra
# Processing Record 33 of Set 10 | luanda
# Processing Record 34 of Set 10 | kiruna
# Processing Record 35 of Set 10 | mizan teferi
# Processing Record 36 of Set 10 | sakaiminato
# Processing Record 37 of Set 10 | matay
# Processing Record 38 of Set 10 | teneguiban
# City not found. Skipping... teneguiban
# Processing Record 39 of Set 10 | camboriu
# City not found. Skipping... camboriu
# Processing Record 40 of Set 10 | beaufort
# Processing Record 41 of Set 10 | tiarei
# Processing Record 42 of Set 10 | chemal
# Processing Record 43 of Set 10 | gigmoto
# Processing Record 44 of Set 10 | lixourion
# Processing Record 45 of Set 10 | burnie
# Processing Record 46 of Set 10 | tjome
# Processing Record 47 of Set 10 | bandar-e lengeh
# Processing Record 48 of Set 10 | caxito
# Processing Record 49 of Set 10 | crestview
# Processing Record 50 of Set 10 | zhuhai
# Processing Record 1 of Set 11 | skotterud
# Processing Record 2 of Set 11 | ambunti
# Processing Record 3 of Set 11 | zhangjiakou
# Processing Record 4 of Set 11 | muncar
# Processing Record 5 of Set 11 | gizo
# Processing Record 6 of Set 11 | pouembout
# Processing Record 7 of Set 11 | bluefield
# Processing Record 8 of Set 11 | tiznit
# Processing Record 9 of Set 11 | vostok
# Processing Record 10 of Set 11 | shimanovsk
# Processing Record 11 of Set 11 | landeck
# Processing Record 12 of Set 11 | angono
# Processing Record 13 of Set 11 | tromso
# Processing Record 14 of Set 11 | linxia
# Processing Record 15 of Set 11 | reforma
# Processing Record 16 of Set 11 | bargal
# City not found. Skipping... bargal
# Processing Record 17 of Set 11 | palaiokhora
# City not found. Skipping... palaiokhora
# Processing Record 18 of Set 11 | douglas
# Processing Record 19 of Set 11 | narsaq
# Processing Record 20 of Set 11 | kuryk
# Processing Record 21 of Set 11 | dalby
# Processing Record 22 of Set 11 | alexandria
# Processing Record 23 of Set 11 | tautira
# Processing Record 24 of Set 11 | bellavista
# Processing Record 25 of Set 11 | misratah
# Processing Record 26 of Set 11 | whitehorse
# Processing Record 27 of Set 11 | culipapa
# City not found. Skipping... culipapa
# Processing Record 28 of Set 11 | cabedelo
# Processing Record 29 of Set 11 | road town
# Processing Record 30 of Set 11 | ciocile
# Processing Record 31 of Set 11 | umzimvubu
# City not found. Skipping... umzimvubu
# Processing Record 32 of Set 11 | mapastepec
# Processing Record 33 of Set 11 | junagarh
# Processing Record 34 of Set 11 | ouegoa
# Processing Record 35 of Set 11 | pedernales
# Processing Record 36 of Set 11 | suffolk
# Processing Record 37 of Set 11 | pacific grove
# Processing Record 38 of Set 11 | yanan
# City not found. Skipping... yanan
# Processing Record 39 of Set 11 | andenes
# Processing Record 40 of Set 11 | elat
# Processing Record 41 of Set 11 | conceicao da barra
# Processing Record 42 of Set 11 | marzuq
# Processing Record 43 of Set 11 | aljezur
# Processing Record 44 of Set 11 | krasnokamensk
# Processing Record 45 of Set 11 | jining
# Processing Record 46 of Set 11 | chagda
# City not found. Skipping... chagda
# Processing Record 47 of Set 11 | tazmalt
# Processing Record 48 of Set 11 | uitenhage
# Processing Record 49 of Set 11 | ixtapa
# Processing Record 50 of Set 11 | muroto
# Processing Record 1 of Set 12 | komsomolets
# Processing Record 2 of Set 12 | sete
# Processing Record 3 of Set 12 | wahran
# City not found. Skipping... wahran
# Processing Record 4 of Set 12 | khandbari
# Processing Record 5 of Set 12 | cockburn town
# Processing Record 6 of Set 12 | mehamn
# Processing Record 7 of Set 12 | richards bay
# Processing Record 8 of Set 12 | tsentralnyy
# City not found. Skipping... tsentralnyy
# Processing Record 9 of Set 12 | pulivendla
# Processing Record 10 of Set 12 | culpeper
# Processing Record 11 of Set 12 | middelburg
# Processing Record 12 of Set 12 | gaoual
# Processing Record 13 of Set 12 | ferrol
# Processing Record 14 of Set 12 | puerto penasco
# Processing Record 15 of Set 12 | dzhusaly
# City not found. Skipping... dzhusaly
# Processing Record 16 of Set 12 | kismayo
# Processing Record 17 of Set 12 | tabiauea
# City not found. Skipping... tabiauea
# Processing Record 18 of Set 12 | danielskuil
# Processing Record 19 of Set 12 | kimbe
# Processing Record 20 of Set 12 | manaure
# Processing Record 21 of Set 12 | ajmer
# Processing Record 22 of Set 12 | chokwe
# Processing Record 23 of Set 12 | jaque
# Processing Record 24 of Set 12 | boyolangu
# Processing Record 25 of Set 12 | zemlyansk
# Processing Record 26 of Set 12 | obigarm
# Processing Record 27 of Set 12 | kristiansund
# Processing Record 28 of Set 12 | arkhara
# Processing Record 29 of Set 12 | iisalmi
# Processing Record 30 of Set 12 | tumannyy
# City not found. Skipping... tumannyy
# Processing Record 31 of Set 12 | mpika
# Processing Record 32 of Set 12 | coahuayana
# Processing Record 33 of Set 12 | grajau
# Processing Record 34 of Set 12 | okhotsk
# Processing Record 35 of Set 12 | brigantine
# Processing Record 36 of Set 12 | talaya
# Processing Record 37 of Set 12 | kapoeta
# Processing Record 38 of Set 12 | westport
# Processing Record 39 of Set 12 | orlovskiy
# Processing Record 40 of Set 12 | hobyo
# Processing Record 41 of Set 12 | belaya gora
# Processing Record 42 of Set 12 | mount gambier
# Processing Record 43 of Set 12 | shchelyayur
# City not found. Skipping... shchelyayur
# Processing Record 44 of Set 12 | hellin
# Processing Record 45 of Set 12 | brasileia
# Processing Record 46 of Set 12 | freilassing
# Processing Record 47 of Set 12 | wasilla
# Processing Record 48 of Set 12 | santa lucia
# Processing Record 49 of Set 12 | vanimo
# Processing Record 50 of Set 12 | usak
# Processing Record 1 of Set 13 | flinders
# Processing Record 2 of Set 13 | niquelandia
# Processing Record 3 of Set 13 | cayenne
# Processing Record 4 of Set 13 | anamur
# Processing Record 5 of Set 13 | santa cruz
# Processing Record 6 of Set 13 | opole
# Processing Record 7 of Set 13 | temerloh
# Processing Record 8 of Set 13 | wenling
# Processing Record 9 of Set 13 | berlevag
# Processing Record 10 of Set 13 | pentecoste
# Processing Record 11 of Set 13 | mahuva
# Processing Record 12 of Set 13 | floro
# Processing Record 13 of Set 13 | maiduguri
# Processing Record 14 of Set 13 | balkhash
# Processing Record 15 of Set 13 | biak
# Processing Record 16 of Set 13 | marsa matruh
# Processing Record 17 of Set 13 | palabuhanratu
# City not found. Skipping... palabuhanratu
# Processing Record 18 of Set 13 | yangjiang
# Processing Record 19 of Set 13 | grand gaube
# Processing Record 20 of Set 13 | vredendal
# Processing Record 21 of Set 13 | roros
# Processing Record 22 of Set 13 | port lincoln
# Processing Record 23 of Set 13 | varzea da palma
# Processing Record 24 of Set 13 | fort saint john
# City not found. Skipping... fort saint john
# Processing Record 25 of Set 13 | boysun
# Processing Record 26 of Set 13 | taperoa
# Processing Record 27 of Set 13 | orlik
# Processing Record 28 of Set 13 | mana
# Processing Record 29 of Set 13 | inuvik
# Processing Record 30 of Set 13 | jinchengjiang
# City not found. Skipping... jinchengjiang
# Processing Record 31 of Set 13 | abakaliki
# Processing Record 32 of Set 13 | umm durman
# City not found. Skipping... umm durman
# Processing Record 33 of Set 13 | poquoson
# Processing Record 34 of Set 13 | zhitikara
# City not found. Skipping... zhitikara
# Processing Record 35 of Set 13 | santo tomas
# Processing Record 36 of Set 13 | excelsior springs
# Processing Record 37 of Set 13 | visnes
# Processing Record 38 of Set 13 | rockhampton
# Processing Record 39 of Set 13 | bandar
# Processing Record 40 of Set 13 | acarau
# Processing Record 41 of Set 13 | sao raimundo das mangabeiras
# Processing Record 42 of Set 13 | sebinkarahisar
# Processing Record 43 of Set 13 | darhan
# Processing Record 44 of Set 13 | ambilobe
# Processing Record 45 of Set 13 | sibu
# Processing Record 46 of Set 13 | senanga
# Processing Record 47 of Set 13 | hofn
# Processing Record 48 of Set 13 | mattawa
# Processing Record 49 of Set 13 | tamsweg
# Processing Record 50 of Set 13 | salta
# Processing Record 1 of Set 14 | kailua
# Processing Record 2 of Set 14 | karratha
# Processing Record 3 of Set 14 | melo
# Processing Record 4 of Set 14 | hemsedal
# Processing Record 5 of Set 14 | chicama
# Processing Record 6 of Set 14 | karachi
# Processing Record 7 of Set 14 | sainte-thecle
# Processing Record 8 of Set 14 | luena
# Processing Record 9 of Set 14 | koungou
# Processing Record 10 of Set 14 | makasar
# Processing Record 11 of Set 14 | la ronge
# Processing Record 12 of Set 14 | birjand
# Processing Record 13 of Set 14 | koppang
# Processing Record 14 of Set 14 | novikovo
# Processing Record 15 of Set 14 | la ciotat
# Processing Record 16 of Set 14 | turiacu
# Processing Record 17 of Set 14 | luwuk
# Processing Record 18 of Set 14 | vaitupu
# City not found. Skipping... vaitupu
# Processing Record 19 of Set 14 | meulaboh
# Processing Record 20 of Set 14 | verkhoyansk
# Processing Record 21 of Set 14 | zayukovo
# Processing Record 22 of Set 14 | listvyagi
# Processing Record 23 of Set 14 | hokitika
# Processing Record 24 of Set 14 | kroya
# Processing Record 25 of Set 14 | keningau
# Processing Record 26 of Set 14 | kendari
# Processing Record 27 of Set 14 | kang
# Processing Record 28 of Set 14 | hami
# Processing Record 29 of Set 14 | benguela
# Processing Record 30 of Set 14 | ivybridge
# Processing Record 31 of Set 14 | ingham
# Processing Record 32 of Set 14 | kariba
# Processing Record 33 of Set 14 | benjamin constant
# Processing Record 34 of Set 14 | mabaruma
# Processing Record 35 of Set 14 | eregli
# Processing Record 36 of Set 14 | kiyasovo
# Processing Record 37 of Set 14 | khuldabad
# Processing Record 38 of Set 14 | copala
# Processing Record 39 of Set 14 | azangaro
# Processing Record 40 of Set 14 | staryy nadym
# Processing Record 41 of Set 14 | bacolod
# Processing Record 42 of Set 14 | kudahuvadhoo
# Processing Record 43 of Set 14 | tatawin
# Processing Record 44 of Set 14 | youhao
# Processing Record 45 of Set 14 | lovozero
# Processing Record 46 of Set 14 | umm lajj
# Processing Record 47 of Set 14 | coevorden
# Processing Record 48 of Set 14 | senigallia
# Processing Record 49 of Set 14 | la palma
# Processing Record 50 of Set 14 | vorukh
# Processing Record 1 of Set 15 | elko
# Processing Record 2 of Set 15 | severnyy
# Processing Record 3 of Set 15 | antsohihy
# Processing Record 4 of Set 15 | ostrov
# Processing Record 5 of Set 15 | caarapo
# Processing Record 6 of Set 15 | shuyskoye
# Processing Record 7 of Set 15 | chapleau
# Processing Record 8 of Set 15 | hohhot
# Processing Record 9 of Set 15 | bahia blanca
# Processing Record 10 of Set 15 | christchurch
# Processing Record 11 of Set 15 | general teran
# Processing Record 12 of Set 15 | tasbuget
# City not found. Skipping... tasbuget
# Processing Record 13 of Set 15 | luba
# Processing Record 14 of Set 15 | sovetskiy
# Processing Record 15 of Set 15 | sakaraha
# Processing Record 16 of Set 15 | sindou
# Processing Record 17 of Set 15 | santa isabel do rio negro
# Processing Record 18 of Set 15 | almeirim
# Processing Record 19 of Set 15 | nemuro
# Processing Record 20 of Set 15 | nioro
# Processing Record 21 of Set 15 | verkhnyaya toyma
# Processing Record 22 of Set 15 | lamisahan
# Processing Record 23 of Set 15 | kawambwa
# Processing Record 24 of Set 15 | paita
# Processing Record 25 of Set 15 | ostrovnoy
# Processing Record 26 of Set 15 | taranto
# Processing Record 27 of Set 15 | kidal
# Processing Record 28 of Set 15 | kaeo
# Processing Record 29 of Set 15 | buchanan
# Processing Record 30 of Set 15 | iguape
# Processing Record 31 of Set 15 | lardos
# Processing Record 32 of Set 15 | margate
# Processing Record 33 of Set 15 | yenagoa
# Processing Record 34 of Set 15 | axim
# Processing Record 35 of Set 15 | lithakia
# Processing Record 36 of Set 15 | maragogi
# Processing Record 37 of Set 15 | port keats
# Processing Record 38 of Set 15 | nabire
# Processing Record 39 of Set 15 | arman
# Processing Record 40 of Set 15 | roberval
# Processing Record 41 of Set 15 | chalus
# Processing Record 42 of Set 15 | cuamba
# Processing Record 43 of Set 15 | diapaga
# Processing Record 44 of Set 15 | saryshagan
# City not found. Skipping... saryshagan
# Processing Record 45 of Set 15 | manturovo
# Processing Record 46 of Set 15 | beaverlodge
# Processing Record 47 of Set 15 | mato verde
# Processing Record 48 of Set 15 | nizwa
# Processing Record 49 of Set 15 | torrevieja
# Processing Record 50 of Set 15 | nivala
# Processing Record 1 of Set 16 | mircea voda
# Processing Record 2 of Set 16 | nevel
# -----------------------------
# Data Retrieval Complete
# -----------------------------

# %%
len(city_data)
# Out:
# 701

# %%
# Convert the array of dictionaries to a Pandas DataFrame.
city_data_df = pd.DataFrame(city_data)
city_data_df.head(10)
# Out:
#           City      Lat       Lng  Max Temp  Humidity  Cloudiness  Wind Speed  \
# 0  New Norfolk -42.7826  147.0587     45.72        70          60        1.01
# 1         Tura  25.5198   90.2201     75.02        98         100        4.79
# 2         Muli   2.9167   73.5667     83.05        70          75       17.47
# 3        Vaini -21.2000 -175.2000     64.56        94          75        4.61
# 4   Marienburg  54.0359   19.0266     75.88        55          73        9.06
# 5       Dikson  73.5069   80.5464     44.10       100         100        2.68
# 6     Thompson  55.7435  -97.8558     62.76        48          75       17.27
# 7      Emerald -23.5333  148.1667     57.34        88           5        6.91
# 8      Ushuaia -54.8000  -68.3000     37.06        93          75       12.66
# 9    Jamestown  42.0970  -79.2353     83.08        85          75        7.00
#
#   Country                 Date Current Description
# 0      AU  2021-08-13 18:27:01       broken clouds
# 1      IN  2021-08-13 18:27:45     overcast clouds
# 2      MV  2021-08-13 18:27:45       broken clouds
# 3      TO  2021-08-13 18:27:45       broken clouds
# 4      PL  2021-08-13 18:27:46       broken clouds
# 5      RU  2021-08-13 18:27:46     overcast clouds
# 6      CA  2021-08-13 18:27:46       broken clouds
# 7      AU  2021-08-13 18:27:47           clear sky
# 8      AR  2021-08-13 18:25:14             drizzle
# 9      US  2021-08-13 18:27:47          light rain

# %%
# Rearrange Columns
new_column_order = ['City','Country','Date','Lat','Lng','Max Temp', 'Humidity','Cloudiness','Wind Speed', 'Current Description']
city_data_df = city_data_df[new_column_order]
city_data_df = city_data_df.round({'Lat': 2, 'Lng': 2})
city_data_df.head(10)
# Out:
#           City Country                 Date    Lat     Lng  Max Temp  \
# 0  New Norfolk      AU  2021-08-13 18:27:01 -42.78  147.06     45.72
# 1         Tura      IN  2021-08-13 18:27:45  25.52   90.22     75.02
# 2         Muli      MV  2021-08-13 18:27:45   2.92   73.57     83.05
# 3        Vaini      TO  2021-08-13 18:27:45 -21.20 -175.20     64.56
# 4   Marienburg      PL  2021-08-13 18:27:46  54.04   19.03     75.88
# 5       Dikson      RU  2021-08-13 18:27:46  73.51   80.55     44.10
# 6     Thompson      CA  2021-08-13 18:27:46  55.74  -97.86     62.76
# 7      Emerald      AU  2021-08-13 18:27:47 -23.53  148.17     57.34
# 8      Ushuaia      AR  2021-08-13 18:25:14 -54.80  -68.30     37.06
# 9    Jamestown      US  2021-08-13 18:27:47  42.10  -79.24     83.08
#
#    Humidity  Cloudiness  Wind Speed Current Description
# 0        70          60        1.01       broken clouds
# 1        98         100        4.79     overcast clouds
# 2        70          75       17.47       broken clouds
# 3        94          75        4.61       broken clouds
# 4        55          73        9.06       broken clouds
# 5       100         100        2.68     overcast clouds
# 6        48          75       17.27       broken clouds
# 7        88           5        6.91           clear sky
# 8        93          75       12.66             drizzle
# 9        85          75        7.00          light rain

# %%
# Create the output file (CSV).
output_data_file = "WeatherPy_Database.csv"

# Export the City_Data into a CSV.
city_data_df.to_csv(output_data_file, index_label="City_ID")
